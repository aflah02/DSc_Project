# %%
import os
import pandas as pd

# %%
data = os.listdir('../Data/Prediction_Metrics_Random_Split/')

# %%
# find all files with metric in name
metric_files = [file for file in data if 'Metrics' in file]

# %%
metric_files
# Out:
# ['FEATURETrans_Metrics.csv',
#  'Raw_Metrics.csv',
#  'SMOTE_FEATURETrans_Metrics.csv',
#  'SMOTE_Metrics.csv']

# %%
# load all files into a list of dataframes
metric_dfs = {i : pd.read_csv('../Data/Prediction_Metrics_Random_Split/' + i) for i in metric_files}

# %%
metric_dfs.keys()
# Out:
# dict_keys(['FEATURETrans_Metrics.csv', 'Raw_Metrics.csv', 'SMOTE_FEATURETrans_Metrics.csv', 'SMOTE_Metrics.csv'])

# %%
metric_dfs['FEATURETrans_Metrics.csv'].sort_values('F1 Score', ascending=False)
# Out:
#    Unnamed: 0                          Model  Accuracy  F1 Score  Precision  \
# 0           0           KNeighborsClassifier  0.982514  0.054871   0.265136
# 1           1         DecisionTreeClassifier  0.983413  0.000000   0.000000
# 2           2         RandomForestClassifier  0.983413  0.000000   0.000000
# 3           3                  MLPClassifier  0.983413  0.000000   0.000000
# 4           4                     GaussianNB  0.983413  0.000000   0.000000
# 5           5  QuadraticDiscriminantAnalysis  0.983413  0.000000   0.000000
#
#      Recall
# 0  0.030602
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  0.000000
# 5  0.000000

# %%
metric_dfs['Raw_Metrics.csv'].sort_values('F1 Score', ascending=False)
# Out:
#    Unnamed: 0                          Model  Accuracy  F1 Score  Precision  \
# 0           0           KNeighborsClassifier  0.987164  0.323822   0.603501
# 5           5  QuadraticDiscriminantAnalysis  0.350303  0.037974   0.019386
# 1           1         DecisionTreeClassifier  0.986109  0.000000   0.000000
# 2           2         RandomForestClassifier  0.986109  0.000000   0.000000
# 3           3                  MLPClassifier  0.986109  0.000000   0.000000
# 4           4                     GaussianNB  0.986109  0.000000   0.000000
#
#      Recall
# 0  0.221276
# 5  0.923115
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  0.000000

# %%
metric_dfs['SMOTE_FEATURETrans_Metrics.csv'].sort_values('F1 Score', ascending=False)
# Out:
#    Unnamed: 0                          Model  Accuracy  F1 Score  Precision  \
# 0           0           KNeighborsClassifier  0.837312  0.853608   0.852812
# 2           2         RandomForestClassifier  0.811867  0.839261   0.798243
# 1           1         DecisionTreeClassifier  0.771226  0.817669   0.733259
# 4           4                     GaussianNB  0.729053  0.761089   0.745438
# 3           3                  MLPClassifier  0.635523  0.675320   0.668005
# 5           5  QuadraticDiscriminantAnalysis  0.444860  0.000000   0.000000
#
#      Recall
# 0  0.854405
# 2  0.884723
# 1  0.924042
# 4  0.777411
# 3  0.682797
# 5  0.000000

# %%
metric_dfs['SMOTE_Metrics.csv'].sort_values('F1 Score', ascending=False)
# Out:
#    Unnamed: 0                          Model  Accuracy  F1 Score  Precision  \
# 2           2         RandomForestClassifier  0.837407  0.844646   0.808391
# 1           1         DecisionTreeClassifier  0.771963  0.800748   0.710811
# 0           0           KNeighborsClassifier  0.770035  0.769036   0.772125
# 5           5  QuadraticDiscriminantAnalysis  0.537835  0.676417   0.520283
# 4           4                     GaussianNB  0.508153  0.669533   0.504037
# 3           3                  MLPClassifier  0.591416  0.652439   0.567514
#
#      Recall
# 2  0.884306
# 1  0.916741
# 0  0.765971
# 5  0.966437
# 4  0.996834
# 3  0.767255
